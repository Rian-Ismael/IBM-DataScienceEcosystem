# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# ## Exercise 2: Create markdown cell with title of the notebook
# Create a markdown cell with the title Data Science Tools and Ecosystem using H1 style heading.
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:35029f38-258b-487e-aee9-9ed0117a872c.png)

# %% [markdown]
# ## Exercise 3 - Create a markdown cell for an introduction
#  This summary aims to give you an overview of the various tools, libraries, and frameworks commonly used in data science workflows, enabling you to navigate and make informed decisions within the data science ecosystem. We cover a wide range of topics, including data manipulation and analysis, machine learning, visualization, and data storage.
#
#  Throughout this notebook, you will find concise explanations and examples of popular tools such as Python libraries like NumPy, Pandas, and SciPy, as well as machine learning frameworks like TensorFlow and PyTorch.
# ![3-intro.png](attachment:43a6bdb1-9d29-4875-8c68-852dc79ac9dd.png)

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 4 - Create a markdown cell to list data science languages
#
# #### Some of the popular languages that Data Scientists use are:
#
# 1. SQL: SQL (Structured Query Language) is essential for working with databases and performing data querying and manipulation.
#
# 2. R: Especially for statistical analysis and data visualization. It provides a wide range of packages like ggplot2.
#
# 3. Julia: Julia is a relatively newer programming language. It combines the simplicity of Python with the speed of languages like C.
#
# ![4-dslanguages.png](attachment:1588fe6b-88e9-4aa0-87a0-a4bd3de7c74d.png)

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 5 - Create a markdown cell to list data science libraries
# #### Some of the commonly used libraries used by Data Scientists include:
# 1. TensorFlow: TensorFlow is a powerful open-source library for machine learning.
# 2. Matplotlib: Matplotlib is a versatile plotting library in Python that enables the creation of a wide range of static, animated, and interactive visualizations.
# 3. Pandas: Pandas is a popular library for data manipulation and analysis.
#
# ![5-dslibraries.png](attachment:a1cfe6b1-5326-499f-9881-46595bd23469.png)

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 6 - Create a markdown cell with a table of Data Science tools
#
#
#
# | Data Science Tools |
# | ----------------- |
# | Jupyter Notebook  |
# | RStudio           |
# | PyCharm           |

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 7 - Create a markdown cell introducing arithmetic expression examples
#
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
x = 6
y = 4
z = 6 + 4
w = ((5 * z) / 5) ** 2
print("result", w - z * 9)
# Out:
# result 10.0

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 8 - Create a code cell to multiply and add numbers
# ### This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 9 - Create a code cell to convert minutes to hours
#
# ### This will convert 200 minutes to hours by diving by 60

# %%
## minutes / 60 --> to hours;

minutes = 200
hours = 200 / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 10 - Insert a markdown cell to list Objectives
# **Objectives:**
#
# - List popular languages for Data Science.
# - Understand the basics of Jupyter Notebook.
# - Familiarize with common data science libraries.
# - Explore data visualization techniques.

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 11 - Create a markdown cell to indicate the Author's name
# ## Author
# ### Rian Ismael

# %% [markdown]
# ## Exercise 12 - Share your notebook through GitHub
# ### Done!

# %% [markdown]
# ## Exercise 13 - Take a screenshot of the first page of the notebook.
# ![Image](attachment:c85b9ead-01e6-4c45-b8e4-dbc0d9cd971f.png)
